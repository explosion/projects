# %% [markdown]
# # Parse Dataset
#
# In this notebook, we are going to parse the dataset obtained from the [PICO Dataset](https://ebm-nlp.herokuapp.com/annotations) ([download](https://github.com/bepnye/EBM-NLP)). Our goal is to turn it into a spaCy binary format. For now, we only need the `ebm_nlp_1_00` dataset that contains the first-phase annotations (P)articipants, (I)ntervention, and (O)utcome.
#
# In terms of the dataset, we'll only need the `annotations/aggregated/starting_spans` since we're only concerned with the P/I/O labels. The `hierarchical` tag is for finer annotations for each category, which we'll probably deal in the latter stages of this project. The documents themselves are already separated by tokens, but we can also access the text if we want to.

# %% [markdown]
# Our strategy for parsing this dataset is that we do this from the annotations first, then match it with the document. Before doing that, I think I should
# check if the PIO tags overlap. If they overlap, I should probably use the `Spans` or `SpanGroup` from spaCy.

# %%
from pathlib import Path
from glob import glob

TEXT_DIR = Path.cwd().parent / "assets" / "raw_data" / "documents"
ANNOTATIONS_DIR = Path.cwd().parent / "assets" / "raw_data" / "annotations" / "aggregated" / "starting_spans"
PARTICIPANTS_DIR = ANNOTATIONS_DIR / "participants"
INTERVENTIONS_DIR = ANNOTATIONS_DIR / "interventions"
OUTCOMES_DIR = ANNOTATIONS_DIR / "outcomes"

# %%
from typing import List
import numpy as np

# Just to be sure, I want to check if some labels overlap
# result = (A XOR B) | (B XOR C)
def xor_threes(a: List[int], b: List[int], c: List[int]):
    """Perform XOR on three vectors

    result = XOR(A, B, C) = (A XOR B) | (B XOR C)
    """
    x = np.logical_xor(a, b)
    y = np.logical_xor(b, c)
    return np.logical_or(x, y)

def get_annotations(filename: Path) -> List[int]:
    data = filename.read_text().split(",")
    # Typecast the labels right away
    data = [int(d) for d in data]
    return data

# Assuming all files are the same, I'll get all the filenames from the participants directory
train_files = [f.name for f in list((PARTICIPANTS_DIR / "train").glob("*_AGGREGATED.ann"))]
overlaps = 0
for file in train_files:
    p = get_annotations(PARTICIPANTS_DIR / "train" / file)
    i = get_annotations(INTERVENTIONS_DIR / "train" / file)
    o = get_annotations(OUTCOMES_DIR / "train" / file)

    res = xor_threes(p, i, o)
    if not all(res):
        print(f"{file}: overlapping labels")
        overlaps += 1
print(f"Total overlaps: {overlaps}/{len(train_files)}")
# Out:
# 2015149_AGGREGATED.ann: overlapping labels
# 9430799_AGGREGATED.ann: overlapping labels
# 9735531_AGGREGATED.ann: overlapping labels
# 18410301_AGGREGATED.ann: overlapping labels
# 3704665_AGGREGATED.ann: overlapping labels
# 16806442_AGGREGATED.ann: overlapping labels
# 19264972_AGGREGATED.ann: overlapping labels
# 19515873_AGGREGATED.ann: overlapping labels
# 23104718_AGGREGATED.ann: overlapping labels
# 4154124_AGGREGATED.ann: overlapping labels
# 10928228_AGGREGATED.ann: overlapping labels
# 17302075_AGGREGATED.ann: overlapping labels
# 11167879_AGGREGATED.ann: overlapping labels
# 7708953_AGGREGATED.ann: overlapping labels
# 22721596_AGGREGATED.ann: overlapping labels
# 23811316_AGGREGATED.ann: overlapping labels
# 21148662_AGGREGATED.ann: overlapping labels
# 15764958_AGGREGATED.ann: overlapping labels
# 5322596_AGGREGATED.ann: overlapping labels
# 9648960_AGGREGATED.ann: overlapping labels
# 19512937_AGGREGATED.ann: overlapping labels
# 23873901_AGGREGATED.ann: overlapping labels
# 9230648_AGGREGATED.ann: overlapping labels
# 11828556_AGGREGATED.ann: overlapping labels
# 25403582_AGGREGATED.ann: overlapping labels
# 10414756_AGGREGATED.ann: overlapping labels
# 21669583_AGGREGATED.ann: overlapping labels
# 8437833_AGGREGATED.ann: overlapping labels
# 418433_AGGREGATED.ann: overlapping labels
# 8435259_AGGREGATED.ann: overlapping labels
# 19545929_AGGREGATED.ann: overlapping labels
# 8673938_AGGREGATED.ann: overlapping labels
# 6416184_AGGREGATED.ann: overlapping labels
# 15233698_AGGREGATED.ann: overlapping labels
# 2975995_AGGREGATED.ann: overlapping labels
# 17035531_AGGREGATED.ann: overlapping labels
# 26214440_AGGREGATED.ann: overlapping labels
# 23075031_AGGREGATED.ann: overlapping labels
# 24435893_AGGREGATED.ann: overlapping labels
# 21193295_AGGREGATED.ann: overlapping labels
# 16879519_AGGREGATED.ann: overlapping labels
# 8521712_AGGREGATED.ann: overlapping labels
# 24852722_AGGREGATED.ann: overlapping labels
# 5378631_AGGREGATED.ann: overlapping labels
# 7006663_AGGREGATED.ann: overlapping labels
# 21042763_AGGREGATED.ann: overlapping labels
# 16204903_AGGREGATED.ann: overlapping labels
# 10201101_AGGREGATED.ann: overlapping labels
# 2148830_AGGREGATED.ann: overlapping labels
# 25670541_AGGREGATED.ann: overlapping labels
# 22079088_AGGREGATED.ann: overlapping labels
# 20488452_AGGREGATED.ann: overlapping labels
# 7148967_AGGREGATED.ann: overlapping labels
# 10078672_AGGREGATED.ann: overlapping labels
# 19017582_AGGREGATED.ann: overlapping labels
# 15267097_AGGREGATED.ann: overlapping labels
# 17244100_AGGREGATED.ann: overlapping labels
# 8015776_AGGREGATED.ann: overlapping labels
# 6350097_AGGREGATED.ann: overlapping labels
# 23578015_AGGREGATED.ann: overlapping labels
# 7481533_AGGREGATED.ann: overlapping labels
# 8549289_AGGREGATED.ann: overlapping labels
# 22692114_AGGREGATED.ann: overlapping labels
# 8217692_AGGREGATED.ann: overlapping labels
# 10926339_AGGREGATED.ann: overlapping labels
# 24679061_AGGREGATED.ann: overlapping labels
# 9003876_AGGREGATED.ann: overlapping labels
# 7936677_AGGREGATED.ann: overlapping labels
# 17719303_AGGREGATED.ann: overlapping labels
# 15591456_AGGREGATED.ann: overlapping labels
# 17356153_AGGREGATED.ann: overlapping labels
# 12687510_AGGREGATED.ann: overlapping labels
# 18448859_AGGREGATED.ann: overlapping labels
# 8123267_AGGREGATED.ann: overlapping labels
# 2085344_AGGREGATED.ann: overlapping labels
# 22838229_AGGREGATED.ann: overlapping labels
# 8376638_AGGREGATED.ann: overlapping labels
# 15701493_AGGREGATED.ann: overlapping labels
# 15845130_AGGREGATED.ann: overlapping labels
# 16730541_AGGREGATED.ann: overlapping labels
# 25643864_AGGREGATED.ann: overlapping labels
# 9665186_AGGREGATED.ann: overlapping labels
# 23173253_AGGREGATED.ann: overlapping labels
# 22972771_AGGREGATED.ann: overlapping labels
# 9572066_AGGREGATED.ann: overlapping labels
# 17037712_AGGREGATED.ann: overlapping labels
# 7826791_AGGREGATED.ann: overlapping labels
# 11501687_AGGREGATED.ann: overlapping labels
# 22821273_AGGREGATED.ann: overlapping labels
# 10437192_AGGREGATED.ann: overlapping labels
# 24161568_AGGREGATED.ann: overlapping labels
# 4016785_AGGREGATED.ann: overlapping labels
# 8770304_AGGREGATED.ann: overlapping labels
# 10871578_AGGREGATED.ann: overlapping labels
# 23547660_AGGREGATED.ann: overlapping labels
# 24915013_AGGREGATED.ann: overlapping labels
# 22101219_AGGREGATED.ann: overlapping labels
# 17625432_AGGREGATED.ann: overlapping labels
# 9796041_AGGREGATED.ann: overlapping labels
# 20854436_AGGREGATED.ann: overlapping labels
# 8276557_AGGREGATED.ann: overlapping labels
# 3516608_AGGREGATED.ann: overlapping labels
# 25017958_AGGREGATED.ann: overlapping labels
# 26449882_AGGREGATED.ann: overlapping labels
# 18843564_AGGREGATED.ann: overlapping labels
# 11305684_AGGREGATED.ann: overlapping labels
# 7799030_AGGREGATED.ann: overlapping labels
# 20061873_AGGREGATED.ann: overlapping labels
# 26385172_AGGREGATED.ann: overlapping labels
# 18067498_AGGREGATED.ann: overlapping labels
# 7595068_AGGREGATED.ann: overlapping labels
# 25142189_AGGREGATED.ann: overlapping labels
# 18582177_AGGREGATED.ann: overlapping labels
# 3923528_AGGREGATED.ann: overlapping labels
# 2275907_AGGREGATED.ann: overlapping labels
# 1862788_AGGREGATED.ann: overlapping labels
# 24216497_AGGREGATED.ann: overlapping labels
# 3885865_AGGREGATED.ann: overlapping labels
# 9801481_AGGREGATED.ann: overlapping labels
# 19135077_AGGREGATED.ann: overlapping labels
# 19591981_AGGREGATED.ann: overlapping labels
# 404962_AGGREGATED.ann: overlapping labels
# 16731138_AGGREGATED.ann: overlapping labels
# 6423162_AGGREGATED.ann: overlapping labels
# 16200817_AGGREGATED.ann: overlapping labels
# 19155155_AGGREGATED.ann: overlapping labels
# 15175435_AGGREGATED.ann: overlapping labels
# 2956874_AGGREGATED.ann: overlapping labels
# 19531038_AGGREGATED.ann: overlapping labels
# 24327720_AGGREGATED.ann: overlapping labels
# 7069027_AGGREGATED.ann: overlapping labels
# 18093356_AGGREGATED.ann: overlapping labels
# 22385102_AGGREGATED.ann: overlapping labels
# 24505318_AGGREGATED.ann: overlapping labels
# 17201540_AGGREGATED.ann: overlapping labels
# 23392460_AGGREGATED.ann: overlapping labels
# 9732932_AGGREGATED.ann: overlapping labels
# 16870004_AGGREGATED.ann: overlapping labels
# 8787889_AGGREGATED.ann: overlapping labels
# 20865678_AGGREGATED.ann: overlapping labels
# 25265769_AGGREGATED.ann: overlapping labels
# 10424316_AGGREGATED.ann: overlapping labels
# 15894964_AGGREGATED.ann: overlapping labels
# 10439497_AGGREGATED.ann: overlapping labels
# 20189663_AGGREGATED.ann: overlapping labels
# 8832526_AGGREGATED.ann: overlapping labels
# 21574725_AGGREGATED.ann: overlapping labels
# 21593282_AGGREGATED.ann: overlapping labels
# 18026891_AGGREGATED.ann: overlapping labels
# 23942708_AGGREGATED.ann: overlapping labels
# 17009251_AGGREGATED.ann: overlapping labels
# 20976617_AGGREGATED.ann: overlapping labels
# 1992319_AGGREGATED.ann: overlapping labels
# 26160997_AGGREGATED.ann: overlapping labels
# 23285026_AGGREGATED.ann: overlapping labels
# 17618948_AGGREGATED.ann: overlapping labels
# 18166533_AGGREGATED.ann: overlapping labels
# 23909380_AGGREGATED.ann: overlapping labels
# 15492789_AGGREGATED.ann: overlapping labels
# 24234676_AGGREGATED.ann: overlapping labels
# 11194696_AGGREGATED.ann: overlapping labels
# 6342928_AGGREGATED.ann: overlapping labels
# 23321692_AGGREGATED.ann: overlapping labels
# 7942578_AGGREGATED.ann: overlapping labels
# 10525558_AGGREGATED.ann: overlapping labels
# 21990307_AGGREGATED.ann: overlapping labels
# 8018457_AGGREGATED.ann: overlapping labels
# 11219757_AGGREGATED.ann: overlapping labels
# 24317552_AGGREGATED.ann: overlapping labels
# 19562475_AGGREGATED.ann: overlapping labels
# 6753858_AGGREGATED.ann: overlapping labels
# 10100592_AGGREGATED.ann: overlapping labels
# 1797999_AGGREGATED.ann: overlapping labels
# 22698563_AGGREGATED.ann: overlapping labels
# 6363798_AGGREGATED.ann: overlapping labels
# 22732975_AGGREGATED.ann: overlapping labels
# 25348544_AGGREGATED.ann: overlapping labels
# 9664917_AGGREGATED.ann: overlapping labels
# 19526613_AGGREGATED.ann: overlapping labels
# 25797097_AGGREGATED.ann: overlapping labels
# 12406050_AGGREGATED.ann: overlapping labels
# 18217284_AGGREGATED.ann: overlapping labels
# 8363113_AGGREGATED.ann: overlapping labels
# 22039290_AGGREGATED.ann: overlapping labels
# 19523697_AGGREGATED.ann: overlapping labels
# 9040453_AGGREGATED.ann: overlapping labels
# 25234479_AGGREGATED.ann: overlapping labels
# 18337049_AGGREGATED.ann: overlapping labels
# 17165495_AGGREGATED.ann: overlapping labels
# 7007454_AGGREGATED.ann: overlapping labels
# 1479049_AGGREGATED.ann: overlapping labels
# 25229605_AGGREGATED.ann: overlapping labels
# 20001837_AGGREGATED.ann: overlapping labels
# 3543069_AGGREGATED.ann: overlapping labels
# 4346973_AGGREGATED.ann: overlapping labels
# 14758586_AGGREGATED.ann: overlapping labels
# 20017819_AGGREGATED.ann: overlapping labels
# 8156515_AGGREGATED.ann: overlapping labels
# 23381958_AGGREGATED.ann: overlapping labels
# 15996057_AGGREGATED.ann: overlapping labels
# 2185458_AGGREGATED.ann: overlapping labels
# 24375082_AGGREGATED.ann: overlapping labels
# 9670112_AGGREGATED.ann: overlapping labels
# 22696626_AGGREGATED.ann: overlapping labels
# 23952636_AGGREGATED.ann: overlapping labels
# 1457432_AGGREGATED.ann: overlapping labels
# 15688961_AGGREGATED.ann: overlapping labels
# 11331721_AGGREGATED.ann: overlapping labels
# 20043831_AGGREGATED.ann: overlapping labels
# 6364880_AGGREGATED.ann: overlapping labels
# 17244294_AGGREGATED.ann: overlapping labels
# 21887489_AGGREGATED.ann: overlapping labels
# 16238662_AGGREGATED.ann: overlapping labels
# 23073171_AGGREGATED.ann: overlapping labels
# 17880325_AGGREGATED.ann: overlapping labels
# 12564611_AGGREGATED.ann: overlapping labels
# 9405728_AGGREGATED.ann: overlapping labels
# 16729400_AGGREGATED.ann: overlapping labels
# 21418212_AGGREGATED.ann: overlapping labels
# 17334477_AGGREGATED.ann: overlapping labels
# 14669937_AGGREGATED.ann: overlapping labels
# 18449445_AGGREGATED.ann: overlapping labels
# 10674680_AGGREGATED.ann: overlapping labels
# 24242260_AGGREGATED.ann: overlapping labels
# 6751144_AGGREGATED.ann: overlapping labels
# 22001361_AGGREGATED.ann: overlapping labels
# 24424141_AGGREGATED.ann: overlapping labels
# 8215273_AGGREGATED.ann: overlapping labels
# 22465904_AGGREGATED.ann: overlapping labels
# 6344196_AGGREGATED.ann: overlapping labels
# 17934527_AGGREGATED.ann: overlapping labels
# 16864886_AGGREGATED.ann: overlapping labels
# 22752489_AGGREGATED.ann: overlapping labels
# 2276106_AGGREGATED.ann: overlapping labels
# 11053333_AGGREGATED.ann: overlapping labels
# 11918753_AGGREGATED.ann: overlapping labels
# 25527253_AGGREGATED.ann: overlapping labels
# 8893393_AGGREGATED.ann: overlapping labels
# 22146934_AGGREGATED.ann: overlapping labels
# 20946200_AGGREGATED.ann: overlapping labels
# 6418295_AGGREGATED.ann: overlapping labels
# 18492829_AGGREGATED.ann: overlapping labels
# 20010551_AGGREGATED.ann: overlapping labels
# 21188521_AGGREGATED.ann: overlapping labels
# 20592840_AGGREGATED.ann: overlapping labels
# 26135372_AGGREGATED.ann: overlapping labels
# 21822764_AGGREGATED.ann: overlapping labels
# 23715475_AGGREGATED.ann: overlapping labels
# 1527133_AGGREGATED.ann: overlapping labels
# 11932879_AGGREGATED.ann: overlapping labels
# 21183747_AGGREGATED.ann: overlapping labels
# 18716736_AGGREGATED.ann: overlapping labels
# 2319047_AGGREGATED.ann: overlapping labels
# 24752311_AGGREGATED.ann: overlapping labels
# 19897177_AGGREGATED.ann: overlapping labels
# 6354030_AGGREGATED.ann: overlapping labels
# 25279666_AGGREGATED.ann: overlapping labels
# 16335132_AGGREGATED.ann: overlapping labels
# 7814306_AGGREGATED.ann: overlapping labels
# 8681312_AGGREGATED.ann: overlapping labels
# 23365106_AGGREGATED.ann: overlapping labels
# 772759_AGGREGATED.ann: overlapping labels
# 24612915_AGGREGATED.ann: overlapping labels
# 22595172_AGGREGATED.ann: overlapping labels
# 18670875_AGGREGATED.ann: overlapping labels
# 10607234_AGGREGATED.ann: overlapping labels
# 21366734_AGGREGATED.ann: overlapping labels
# 10209728_AGGREGATED.ann: overlapping labels
# 20386431_AGGREGATED.ann: overlapping labels
# 21324150_AGGREGATED.ann: overlapping labels
# 26208985_AGGREGATED.ann: overlapping labels
# 17950167_AGGREGATED.ann: overlapping labels
# 8686245_AGGREGATED.ann: overlapping labels
# 12970516_AGGREGATED.ann: overlapping labels
# 15283485_AGGREGATED.ann: overlapping labels
# 12160584_AGGREGATED.ann: overlapping labels
# 8549538_AGGREGATED.ann: overlapping labels
# 24286965_AGGREGATED.ann: overlapping labels
# 16190799_AGGREGATED.ann: overlapping labels
# 17700649_AGGREGATED.ann: overlapping labels
# 21632816_AGGREGATED.ann: overlapping labels
# 6752752_AGGREGATED.ann: overlapping labels
# 10963640_AGGREGATED.ann: overlapping labels
# 3337028_AGGREGATED.ann: overlapping labels
# 2647294_AGGREGATED.ann: overlapping labels
# 12120773_AGGREGATED.ann: overlapping labels
# 22631032_AGGREGATED.ann: overlapping labels
# 12058842_AGGREGATED.ann: overlapping labels
# 15180835_AGGREGATED.ann: overlapping labels
# 9647338_AGGREGATED.ann: overlapping labels
# 25572620_AGGREGATED.ann: overlapping labels
# 9932558_AGGREGATED.ann: overlapping labels
# 20865676_AGGREGATED.ann: overlapping labels
# 25313065_AGGREGATED.ann: overlapping labels
# 10337847_AGGREGATED.ann: overlapping labels
# 17051443_AGGREGATED.ann: overlapping labels
# 10889804_AGGREGATED.ann: overlapping labels
# 19301086_AGGREGATED.ann: overlapping labels
# 1829841_AGGREGATED.ann: overlapping labels
# 20406576_AGGREGATED.ann: overlapping labels
# 26551184_AGGREGATED.ann: overlapping labels
# 17617281_AGGREGATED.ann: overlapping labels
# 305873_AGGREGATED.ann: overlapping labels
# 26035186_AGGREGATED.ann: overlapping labels
# 21996342_AGGREGATED.ann: overlapping labels
# 16160627_AGGREGATED.ann: overlapping labels
# 22678947_AGGREGATED.ann: overlapping labels
# 18672629_AGGREGATED.ann: overlapping labels
# 6403413_AGGREGATED.ann: overlapping labels
# 17445928_AGGREGATED.ann: overlapping labels
# 22983407_AGGREGATED.ann: overlapping labels
# 12492271_AGGREGATED.ann: overlapping labels
# 7888291_AGGREGATED.ann: overlapping labels
# 8656171_AGGREGATED.ann: overlapping labels
# 18957157_AGGREGATED.ann: overlapping labels
# 22965298_AGGREGATED.ann: overlapping labels
# 21660428_AGGREGATED.ann: overlapping labels
# 387204_AGGREGATED.ann: overlapping labels
# 15302787_AGGREGATED.ann: overlapping labels
# 19915222_AGGREGATED.ann: overlapping labels
# 22156577_AGGREGATED.ann: overlapping labels
# 8213019_AGGREGATED.ann: overlapping labels
# 23511149_AGGREGATED.ann: overlapping labels
# 22608375_AGGREGATED.ann: overlapping labels
# 24268858_AGGREGATED.ann: overlapping labels
# 16266472_AGGREGATED.ann: overlapping labels
# 22768793_AGGREGATED.ann: overlapping labels
# 2180462_AGGREGATED.ann: overlapping labels
# 11994052_AGGREGATED.ann: overlapping labels
# 16562630_AGGREGATED.ann: overlapping labels
# 19109835_AGGREGATED.ann: overlapping labels
# 1497864_AGGREGATED.ann: overlapping labels
# 7298122_AGGREGATED.ann: overlapping labels
# 17999404_AGGREGATED.ann: overlapping labels
# 7825420_AGGREGATED.ann: overlapping labels
# 23410851_AGGREGATED.ann: overlapping labels
# 9351400_AGGREGATED.ann: overlapping labels
# 19284641_AGGREGATED.ann: overlapping labels
# 1119679_AGGREGATED.ann: overlapping labels
# 20680681_AGGREGATED.ann: overlapping labels
# 14996144_AGGREGATED.ann: overlapping labels
# 17175376_AGGREGATED.ann: overlapping labels
# 6391269_AGGREGATED.ann: overlapping labels
# 22735897_AGGREGATED.ann: overlapping labels
# 17404138_AGGREGATED.ann: overlapping labels
# 8069156_AGGREGATED.ann: overlapping labels
# 15541087_AGGREGATED.ann: overlapping labels
# 18795522_AGGREGATED.ann: overlapping labels
# 20973459_AGGREGATED.ann: overlapping labels
# 15304616_AGGREGATED.ann: overlapping labels
# 18606932_AGGREGATED.ann: overlapping labels
# 7655889_AGGREGATED.ann: overlapping labels
# 24447434_AGGREGATED.ann: overlapping labels
# 21531178_AGGREGATED.ann: overlapping labels
# 24534682_AGGREGATED.ann: overlapping labels
# 16981667_AGGREGATED.ann: overlapping labels
# 22789149_AGGREGATED.ann: overlapping labels
# 18783079_AGGREGATED.ann: overlapping labels
# 17438178_AGGREGATED.ann: overlapping labels
# 25428632_AGGREGATED.ann: overlapping labels
# 12850861_AGGREGATED.ann: overlapping labels
# 23613224_AGGREGATED.ann: overlapping labels
# 15886667_AGGREGATED.ann: overlapping labels
# 4198313_AGGREGATED.ann: overlapping labels
# 9449870_AGGREGATED.ann: overlapping labels
# 21270510_AGGREGATED.ann: overlapping labels
# 19073386_AGGREGATED.ann: overlapping labels
# 7881454_AGGREGATED.ann: overlapping labels
# 1678925_AGGREGATED.ann: overlapping labels
# 10592853_AGGREGATED.ann: overlapping labels
# 2644391_AGGREGATED.ann: overlapping labels
# 15838684_AGGREGATED.ann: overlapping labels
# 12814457_AGGREGATED.ann: overlapping labels
# 23463854_AGGREGATED.ann: overlapping labels
# 24807158_AGGREGATED.ann: overlapping labels
# 7591314_AGGREGATED.ann: overlapping labels
# 25920470_AGGREGATED.ann: overlapping labels
# 12407485_AGGREGATED.ann: overlapping labels
# 22395144_AGGREGATED.ann: overlapping labels
# 7674231_AGGREGATED.ann: overlapping labels
# 14599236_AGGREGATED.ann: overlapping labels
# 1904908_AGGREGATED.ann: overlapping labels
# 24101715_AGGREGATED.ann: overlapping labels
# 9864127_AGGREGATED.ann: overlapping labels
# 11322670_AGGREGATED.ann: overlapping labels
# 25978402_AGGREGATED.ann: overlapping labels
# 25719544_AGGREGATED.ann: overlapping labels
# 26122384_AGGREGATED.ann: overlapping labels
# 25342184_AGGREGATED.ann: overlapping labels
# 7944932_AGGREGATED.ann: overlapping labels
# 23778526_AGGREGATED.ann: overlapping labels
# 22853706_AGGREGATED.ann: overlapping labels
# 18004169_AGGREGATED.ann: overlapping labels
# 17069543_AGGREGATED.ann: overlapping labels
# 16377918_AGGREGATED.ann: overlapping labels
# 17977295_AGGREGATED.ann: overlapping labels
# 19040172_AGGREGATED.ann: overlapping labels
# 22020134_AGGREGATED.ann: overlapping labels
# 20042310_AGGREGATED.ann: overlapping labels
# 15466792_AGGREGATED.ann: overlapping labels
# 12193353_AGGREGATED.ann: overlapping labels
# 3710012_AGGREGATED.ann: overlapping labels
# 24089423_AGGREGATED.ann: overlapping labels
# 23827399_AGGREGATED.ann: overlapping labels
# 16214598_AGGREGATED.ann: overlapping labels
# 21090563_AGGREGATED.ann: overlapping labels
# 23782653_AGGREGATED.ann: overlapping labels
# 19702485_AGGREGATED.ann: overlapping labels
# 25488965_AGGREGATED.ann: overlapping labels
# 25304364_AGGREGATED.ann: overlapping labels
# 8509099_AGGREGATED.ann: overlapping labels
# 24998293_AGGREGATED.ann: overlapping labels
# 18298579_AGGREGATED.ann: overlapping labels
# 2014978_AGGREGATED.ann: overlapping labels
# 23944980_AGGREGATED.ann: overlapping labels
# 1631861_AGGREGATED.ann: overlapping labels
# 12844393_AGGREGATED.ann: overlapping labels
# 16316486_AGGREGATED.ann: overlapping labels
# 16731878_AGGREGATED.ann: overlapping labels
# 23716291_AGGREGATED.ann: overlapping labels
# 24293165_AGGREGATED.ann: overlapping labels
# 6131800_AGGREGATED.ann: overlapping labels
# 24323035_AGGREGATED.ann: overlapping labels
# 11034038_AGGREGATED.ann: overlapping labels
# 7564450_AGGREGATED.ann: overlapping labels
# 19590523_AGGREGATED.ann: overlapping labels
# 8616024_AGGREGATED.ann: overlapping labels
# 1920171_AGGREGATED.ann: overlapping labels
# 24402830_AGGREGATED.ann: overlapping labels
# 16601648_AGGREGATED.ann: overlapping labels
# 1457622_AGGREGATED.ann: overlapping labels
# 18618513_AGGREGATED.ann: overlapping labels
# 20638818_AGGREGATED.ann: overlapping labels
# 25022248_AGGREGATED.ann: overlapping labels
# 11360574_AGGREGATED.ann: overlapping labels
# 22906113_AGGREGATED.ann: overlapping labels
# 16882628_AGGREGATED.ann: overlapping labels
# 20390261_AGGREGATED.ann: overlapping labels
# 10674229_AGGREGATED.ann: overlapping labels
# 2205798_AGGREGATED.ann: overlapping labels
# 12443948_AGGREGATED.ann: overlapping labels
# 24345974_AGGREGATED.ann: overlapping labels
# 25365653_AGGREGATED.ann: overlapping labels
# 2218657_AGGREGATED.ann: overlapping labels
# 21392837_AGGREGATED.ann: overlapping labels
# 18328868_AGGREGATED.ann: overlapping labels
# 6122555_AGGREGATED.ann: overlapping labels
# 1667693_AGGREGATED.ann: overlapping labels
# 8015504_AGGREGATED.ann: overlapping labels
# 2859779_AGGREGATED.ann: overlapping labels
# 22968615_AGGREGATED.ann: overlapping labels
# 23699515_AGGREGATED.ann: overlapping labels
# 9818688_AGGREGATED.ann: overlapping labels
# 23815478_AGGREGATED.ann: overlapping labels
# 10754477_AGGREGATED.ann: overlapping labels
# 23095369_AGGREGATED.ann: overlapping labels
# 3960619_AGGREGATED.ann: overlapping labels
# 18726150_AGGREGATED.ann: overlapping labels
# 23836550_AGGREGATED.ann: overlapping labels
# 24076133_AGGREGATED.ann: overlapping labels
# 17078451_AGGREGATED.ann: overlapping labels
# 27532829_AGGREGATED.ann: overlapping labels
# 19092729_AGGREGATED.ann: overlapping labels
# 24961537_AGGREGATED.ann: overlapping labels
# 15947531_AGGREGATED.ann: overlapping labels
# 9225710_AGGREGATED.ann: overlapping labels
# 9778067_AGGREGATED.ann: overlapping labels
# 11751780_AGGREGATED.ann: overlapping labels
# 17357577_AGGREGATED.ann: overlapping labels
# 22692116_AGGREGATED.ann: overlapping labels
# 21998264_AGGREGATED.ann: overlapping labels
# 24532106_AGGREGATED.ann: overlapping labels
# 24662027_AGGREGATED.ann: overlapping labels
# 19480863_AGGREGATED.ann: overlapping labels
# 18056791_AGGREGATED.ann: overlapping labels
# 24840596_AGGREGATED.ann: overlapping labels
# 21327867_AGGREGATED.ann: overlapping labels
# 3081148_AGGREGATED.ann: overlapping labels
# 19330493_AGGREGATED.ann: overlapping labels
# 24083350_AGGREGATED.ann: overlapping labels
# 2939214_AGGREGATED.ann: overlapping labels
# 18512510_AGGREGATED.ann: overlapping labels
# 25801501_AGGREGATED.ann: overlapping labels
# 17297323_AGGREGATED.ann: overlapping labels
# 9849475_AGGREGATED.ann: overlapping labels
# 11352886_AGGREGATED.ann: overlapping labels
# 7527453_AGGREGATED.ann: overlapping labels
# 24885187_AGGREGATED.ann: overlapping labels
# 21930490_AGGREGATED.ann: overlapping labels
# 20726255_AGGREGATED.ann: overlapping labels
# 20008622_AGGREGATED.ann: overlapping labels
# 20536364_AGGREGATED.ann: overlapping labels
# 11022066_AGGREGATED.ann: overlapping labels
# 8932546_AGGREGATED.ann: overlapping labels
# 7650233_AGGREGATED.ann: overlapping labels
# 16337719_AGGREGATED.ann: overlapping labels
# 19781408_AGGREGATED.ann: overlapping labels
# 12370849_AGGREGATED.ann: overlapping labels
# 16452103_AGGREGATED.ann: overlapping labels
# 7489845_AGGREGATED.ann: overlapping labels
# 14716650_AGGREGATED.ann: overlapping labels
# 21575074_AGGREGATED.ann: overlapping labels
# 9316683_AGGREGATED.ann: overlapping labels
# 23016708_AGGREGATED.ann: overlapping labels
# 7887018_AGGREGATED.ann: overlapping labels
# 22131601_AGGREGATED.ann: overlapping labels
# 17383295_AGGREGATED.ann: overlapping labels
# 24158898_AGGREGATED.ann: overlapping labels
# 11265037_AGGREGATED.ann: overlapping labels
# 2187009_AGGREGATED.ann: overlapping labels
# 1364154_AGGREGATED.ann: overlapping labels
# 25526832_AGGREGATED.ann: overlapping labels
# 15994014_AGGREGATED.ann: overlapping labels
# 19786383_AGGREGATED.ann: overlapping labels
# 20813580_AGGREGATED.ann: overlapping labels
# 20447037_AGGREGATED.ann: overlapping labels
# 22511135_AGGREGATED.ann: overlapping labels
# 10624759_AGGREGATED.ann: overlapping labels
# 2112233_AGGREGATED.ann: overlapping labels
# 12531809_AGGREGATED.ann: overlapping labels
# 23101743_AGGREGATED.ann: overlapping labels
# 12480867_AGGREGATED.ann: overlapping labels
# 16600723_AGGREGATED.ann: overlapping labels
# 7646610_AGGREGATED.ann: overlapping labels
# 21543343_AGGREGATED.ann: overlapping labels
# 16904524_AGGREGATED.ann: overlapping labels
# 25437533_AGGREGATED.ann: overlapping labels
# 19188136_AGGREGATED.ann: overlapping labels
# 20004739_AGGREGATED.ann: overlapping labels
# 2696035_AGGREGATED.ann: overlapping labels
# 15189781_AGGREGATED.ann: overlapping labels
# 21207788_AGGREGATED.ann: overlapping labels
# 8930174_AGGREGATED.ann: overlapping labels
# 25898050_AGGREGATED.ann: overlapping labels
# 24915929_AGGREGATED.ann: overlapping labels
# 22669453_AGGREGATED.ann: overlapping labels
# 19242343_AGGREGATED.ann: overlapping labels
# 2691638_AGGREGATED.ann: overlapping labels
# 25673113_AGGREGATED.ann: overlapping labels
# 2107116_AGGREGATED.ann: overlapping labels
# 1922235_AGGREGATED.ann: overlapping labels
# 18787937_AGGREGATED.ann: overlapping labels
# 9172668_AGGREGATED.ann: overlapping labels
# 1741218_AGGREGATED.ann: overlapping labels
# 11876893_AGGREGATED.ann: overlapping labels
# 15012924_AGGREGATED.ann: overlapping labels
# 7540705_AGGREGATED.ann: overlapping labels
# 2339965_AGGREGATED.ann: overlapping labels
# 8077143_AGGREGATED.ann: overlapping labels
# 15154956_AGGREGATED.ann: overlapping labels
# 24097277_AGGREGATED.ann: overlapping labels
# 20472253_AGGREGATED.ann: overlapping labels
# 20484550_AGGREGATED.ann: overlapping labels
# 24007198_AGGREGATED.ann: overlapping labels
# 24282036_AGGREGATED.ann: overlapping labels
# 23379240_AGGREGATED.ann: overlapping labels
# 7924475_AGGREGATED.ann: overlapping labels
# 8323420_AGGREGATED.ann: overlapping labels
# 19797985_AGGREGATED.ann: overlapping labels
# 22740508_AGGREGATED.ann: overlapping labels
# 3503390_AGGREGATED.ann: overlapping labels
# 25424398_AGGREGATED.ann: overlapping labels
# 22492697_AGGREGATED.ann: overlapping labels
# 23084254_AGGREGATED.ann: overlapping labels
# 23134960_AGGREGATED.ann: overlapping labels
# 8669042_AGGREGATED.ann: overlapping labels
# 10837440_AGGREGATED.ann: overlapping labels
# 20608027_AGGREGATED.ann: overlapping labels
# 12422941_AGGREGATED.ann: overlapping labels
# 23428834_AGGREGATED.ann: overlapping labels
# 12496956_AGGREGATED.ann: overlapping labels
# 15053783_AGGREGATED.ann: overlapping labels
# 3475309_AGGREGATED.ann: overlapping labels
# 7617857_AGGREGATED.ann: overlapping labels
# 22147942_AGGREGATED.ann: overlapping labels
# 15249792_AGGREGATED.ann: overlapping labels
# 23893098_AGGREGATED.ann: overlapping labels
# 18983318_AGGREGATED.ann: overlapping labels
# 3896455_AGGREGATED.ann: overlapping labels
# 10374155_AGGREGATED.ann: overlapping labels
# 2959901_AGGREGATED.ann: overlapping labels
# 17046466_AGGREGATED.ann: overlapping labels
# 1634173_AGGREGATED.ann: overlapping labels
# 23566237_AGGREGATED.ann: overlapping labels
# 10338217_AGGREGATED.ann: overlapping labels
# 11708589_AGGREGATED.ann: overlapping labels
# 24713181_AGGREGATED.ann: overlapping labels
# 21918912_AGGREGATED.ann: overlapping labels
# 6409006_AGGREGATED.ann: overlapping labels
# 25915138_AGGREGATED.ann: overlapping labels
# 12067044_AGGREGATED.ann: overlapping labels
# 17467265_AGGREGATED.ann: overlapping labels
# 21034619_AGGREGATED.ann: overlapping labels
# 16824797_AGGREGATED.ann: overlapping labels
# 24350695_AGGREGATED.ann: overlapping labels
# 24898574_AGGREGATED.ann: overlapping labels
# 12073766_AGGREGATED.ann: overlapping labels
# 17089419_AGGREGATED.ann: overlapping labels
# 1391736_AGGREGATED.ann: overlapping labels
# 9499947_AGGREGATED.ann: overlapping labels
# 6367857_AGGREGATED.ann: overlapping labels
# 8332150_AGGREGATED.ann: overlapping labels
# 26122982_AGGREGATED.ann: overlapping labels
# 2936772_AGGREGATED.ann: overlapping labels
# 9607867_AGGREGATED.ann: overlapping labels
# 12117831_AGGREGATED.ann: overlapping labels
# 22066973_AGGREGATED.ann: overlapping labels
# 24320862_AGGREGATED.ann: overlapping labels
# 7036084_AGGREGATED.ann: overlapping labels
# 8436638_AGGREGATED.ann: overlapping labels
# 16939848_AGGREGATED.ann: overlapping labels
# 23405154_AGGREGATED.ann: overlapping labels
# 12718385_AGGREGATED.ann: overlapping labels
# 12511152_AGGREGATED.ann: overlapping labels
# 16435344_AGGREGATED.ann: overlapping labels
# 23605599_AGGREGATED.ann: overlapping labels
# 17093162_AGGREGATED.ann: overlapping labels
# 9808499_AGGREGATED.ann: overlapping labels
# 8780429_AGGREGATED.ann: overlapping labels
# 10188144_AGGREGATED.ann: overlapping labels
# 939970_AGGREGATED.ann: overlapping labels
# 19001830_AGGREGATED.ann: overlapping labels
# 12418582_AGGREGATED.ann: overlapping labels
# 18235151_AGGREGATED.ann: overlapping labels
# 9400786_AGGREGATED.ann: overlapping labels
# 19853700_AGGREGATED.ann: overlapping labels
# 23993773_AGGREGATED.ann: overlapping labels
# 7635420_AGGREGATED.ann: overlapping labels
# 18235123_AGGREGATED.ann: overlapping labels
# 14980919_AGGREGATED.ann: overlapping labels
# 14628158_AGGREGATED.ann: overlapping labels
# 384024_AGGREGATED.ann: overlapping labels
# 4037540_AGGREGATED.ann: overlapping labels
# 9129469_AGGREGATED.ann: overlapping labels
# 16822100_AGGREGATED.ann: overlapping labels
# 12769155_AGGREGATED.ann: overlapping labels
# 16214437_AGGREGATED.ann: overlapping labels
# 23812661_AGGREGATED.ann: overlapping labels
# 7640140_AGGREGATED.ann: overlapping labels
# 20338811_AGGREGATED.ann: overlapping labels
# 17477785_AGGREGATED.ann: overlapping labels
# 1818543_AGGREGATED.ann: overlapping labels
# 25594611_AGGREGATED.ann: overlapping labels
# 11218508_AGGREGATED.ann: overlapping labels
# 7969211_AGGREGATED.ann: overlapping labels
# 21987240_AGGREGATED.ann: overlapping labels
# 11471578_AGGREGATED.ann: overlapping labels
# 11709366_AGGREGATED.ann: overlapping labels
# 5410150_AGGREGATED.ann: overlapping labels
# 1927197_AGGREGATED.ann: overlapping labels
# 24920862_AGGREGATED.ann: overlapping labels
# 15091267_AGGREGATED.ann: overlapping labels
# 7259216_AGGREGATED.ann: overlapping labels
# 2105256_AGGREGATED.ann: overlapping labels
# 9109702_AGGREGATED.ann: overlapping labels
# 10506815_AGGREGATED.ann: overlapping labels
# 6366148_AGGREGATED.ann: overlapping labels
# 15940774_AGGREGATED.ann: overlapping labels
# 15764256_AGGREGATED.ann: overlapping labels
# 23942329_AGGREGATED.ann: overlapping labels
# 11465651_AGGREGATED.ann: overlapping labels
# 16792607_AGGREGATED.ann: overlapping labels
# 3183852_AGGREGATED.ann: overlapping labels
# 26882812_AGGREGATED.ann: overlapping labels
# 3602327_AGGREGATED.ann: overlapping labels
# 7620474_AGGREGATED.ann: overlapping labels
# 12604982_AGGREGATED.ann: overlapping labels
# 8277075_AGGREGATED.ann: overlapping labels
# 12834936_AGGREGATED.ann: overlapping labels
# 11028492_AGGREGATED.ann: overlapping labels
# 21909698_AGGREGATED.ann: overlapping labels
# 23113962_AGGREGATED.ann: overlapping labels
# 8561059_AGGREGATED.ann: overlapping labels
# 23205521_AGGREGATED.ann: overlapping labels
# 14996351_AGGREGATED.ann: overlapping labels
# 16177585_AGGREGATED.ann: overlapping labels
# 23065117_AGGREGATED.ann: overlapping labels
# 7593698_AGGREGATED.ann: overlapping labels
# 16890144_AGGREGATED.ann: overlapping labels
# 20587582_AGGREGATED.ann: overlapping labels
# 12394700_AGGREGATED.ann: overlapping labels
# 10213233_AGGREGATED.ann: overlapping labels
# 21309374_AGGREGATED.ann: overlapping labels
# 18849616_AGGREGATED.ann: overlapping labels
# 6189335_AGGREGATED.ann: overlapping labels
# 4220015_AGGREGATED.ann: overlapping labels
# 18717189_AGGREGATED.ann: overlapping labels
# 9267377_AGGREGATED.ann: overlapping labels
# 384574_AGGREGATED.ann: overlapping labels
# 20522464_AGGREGATED.ann: overlapping labels
# 6403021_AGGREGATED.ann: overlapping labels
# 12377836_AGGREGATED.ann: overlapping labels
# 8198938_AGGREGATED.ann: overlapping labels
# 26742304_AGGREGATED.ann: overlapping labels
# 8908106_AGGREGATED.ann: overlapping labels
# 15678729_AGGREGATED.ann: overlapping labels
# 12546485_AGGREGATED.ann: overlapping labels
# 14589718_AGGREGATED.ann: overlapping labels
# 7104637_AGGREGATED.ann: overlapping labels
# 17074147_AGGREGATED.ann: overlapping labels
# 24628747_AGGREGATED.ann: overlapping labels
# 8428787_AGGREGATED.ann: overlapping labels
# 15914517_AGGREGATED.ann: overlapping labels
# 21067912_AGGREGATED.ann: overlapping labels
# 24830937_AGGREGATED.ann: overlapping labels
# 25062129_AGGREGATED.ann: overlapping labels
# 20434046_AGGREGATED.ann: overlapping labels
# 23385110_AGGREGATED.ann: overlapping labels
# 15572491_AGGREGATED.ann: overlapping labels
# 11378004_AGGREGATED.ann: overlapping labels
# 23972722_AGGREGATED.ann: overlapping labels
# 3549874_AGGREGATED.ann: overlapping labels
# 16230666_AGGREGATED.ann: overlapping labels
# 20167900_AGGREGATED.ann: overlapping labels
# 2890442_AGGREGATED.ann: overlapping labels
# 22265360_AGGREGATED.ann: overlapping labels
# 22412171_AGGREGATED.ann: overlapping labels
# 24557758_AGGREGATED.ann: overlapping labels
# 10637238_AGGREGATED.ann: overlapping labels
# 5575706_AGGREGATED.ann: overlapping labels
# 50611_AGGREGATED.ann: overlapping labels
# 21445888_AGGREGATED.ann: overlapping labels
# 3830804_AGGREGATED.ann: overlapping labels
# 16733916_AGGREGATED.ann: overlapping labels
# 16887481_AGGREGATED.ann: overlapping labels
# 18341602_AGGREGATED.ann: overlapping labels
# 10380161_AGGREGATED.ann: overlapping labels
# 7118776_AGGREGATED.ann: overlapping labels
# 17490976_AGGREGATED.ann: overlapping labels
# 18242415_AGGREGATED.ann: overlapping labels
# 15224298_AGGREGATED.ann: overlapping labels
# 25795413_AGGREGATED.ann: overlapping labels
# 25644279_AGGREGATED.ann: overlapping labels
# 2586565_AGGREGATED.ann: overlapping labels
# 12630606_AGGREGATED.ann: overlapping labels
# 17959958_AGGREGATED.ann: overlapping labels
# 12049860_AGGREGATED.ann: overlapping labels
# 7699494_AGGREGATED.ann: overlapping labels
# 19192127_AGGREGATED.ann: overlapping labels
# 22370992_AGGREGATED.ann: overlapping labels
# 10037531_AGGREGATED.ann: overlapping labels
# 25122429_AGGREGATED.ann: overlapping labels
# 25532076_AGGREGATED.ann: overlapping labels
# 7654128_AGGREGATED.ann: overlapping labels
# 3653128_AGGREGATED.ann: overlapping labels
# 17047022_AGGREGATED.ann: overlapping labels
# 3881176_AGGREGATED.ann: overlapping labels
# 1307461_AGGREGATED.ann: overlapping labels
# 23647705_AGGREGATED.ann: overlapping labels
# 288173_AGGREGATED.ann: overlapping labels
# 10348763_AGGREGATED.ann: overlapping labels
# 9099447_AGGREGATED.ann: overlapping labels
# 11485124_AGGREGATED.ann: overlapping labels
# 18051010_AGGREGATED.ann: overlapping labels
# 24916506_AGGREGATED.ann: overlapping labels
# 16940738_AGGREGATED.ann: overlapping labels
# 25519880_AGGREGATED.ann: overlapping labels
# 15612617_AGGREGATED.ann: overlapping labels
# 21931984_AGGREGATED.ann: overlapping labels
# 1673324_AGGREGATED.ann: overlapping labels
# 16394797_AGGREGATED.ann: overlapping labels
# 447787_AGGREGATED.ann: overlapping labels
# 7011331_AGGREGATED.ann: overlapping labels
# 20548043_AGGREGATED.ann: overlapping labels
# 4077545_AGGREGATED.ann: overlapping labels
# 10663363_AGGREGATED.ann: overlapping labels
# 8056005_AGGREGATED.ann: overlapping labels
# 10778276_AGGREGATED.ann: overlapping labels
# 1289508_AGGREGATED.ann: overlapping labels
# 19535468_AGGREGATED.ann: overlapping labels
# 23592849_AGGREGATED.ann: overlapping labels
# 3803417_AGGREGATED.ann: overlapping labels
# 11384820_AGGREGATED.ann: overlapping labels
# 26485385_AGGREGATED.ann: overlapping labels
# 8877260_AGGREGATED.ann: overlapping labels
# 16686565_AGGREGATED.ann: overlapping labels
# 15975721_AGGREGATED.ann: overlapping labels
# 11570022_AGGREGATED.ann: overlapping labels
# 11978262_AGGREGATED.ann: overlapping labels
# 18353086_AGGREGATED.ann: overlapping labels
# 15608043_AGGREGATED.ann: overlapping labels
# 10816058_AGGREGATED.ann: overlapping labels
# 7824501_AGGREGATED.ann: overlapping labels
# 15652441_AGGREGATED.ann: overlapping labels
# 9231814_AGGREGATED.ann: overlapping labels
# 23407221_AGGREGATED.ann: overlapping labels
# 1467386_AGGREGATED.ann: overlapping labels
# 14625812_AGGREGATED.ann: overlapping labels
# 10757250_AGGREGATED.ann: overlapping labels
# 10901647_AGGREGATED.ann: overlapping labels
# 25084009_AGGREGATED.ann: overlapping labels
# 12031821_AGGREGATED.ann: overlapping labels
# 26448791_AGGREGATED.ann: overlapping labels
# 11545629_AGGREGATED.ann: overlapping labels
# 3296982_AGGREGATED.ann: overlapping labels
# 22414705_AGGREGATED.ann: overlapping labels
# 2204661_AGGREGATED.ann: overlapping labels
# 25629971_AGGREGATED.ann: overlapping labels
# 25346345_AGGREGATED.ann: overlapping labels
# 6341410_AGGREGATED.ann: overlapping labels
# 10489959_AGGREGATED.ann: overlapping labels
# 17252578_AGGREGATED.ann: overlapping labels
# 1326339_AGGREGATED.ann: overlapping labels
# 24189342_AGGREGATED.ann: overlapping labels
# 7857500_AGGREGATED.ann: overlapping labels
# 17574073_AGGREGATED.ann: overlapping labels
# 11408369_AGGREGATED.ann: overlapping labels
# 14623199_AGGREGATED.ann: overlapping labels
# 14732749_AGGREGATED.ann: overlapping labels
# 23955236_AGGREGATED.ann: overlapping labels
# 20569998_AGGREGATED.ann: overlapping labels
# 11369627_AGGREGATED.ann: overlapping labels
# 25798729_AGGREGATED.ann: overlapping labels
# 7705531_AGGREGATED.ann: overlapping labels
# 25524655_AGGREGATED.ann: overlapping labels
# 3030386_AGGREGATED.ann: overlapping labels
# 18522171_AGGREGATED.ann: overlapping labels
# 22459310_AGGREGATED.ann: overlapping labels
# 17849093_AGGREGATED.ann: overlapping labels
# 12183788_AGGREGATED.ann: overlapping labels
# 16740812_AGGREGATED.ann: overlapping labels
# 6871470_AGGREGATED.ann: overlapping labels
# 10678548_AGGREGATED.ann: overlapping labels
# 8712092_AGGREGATED.ann: overlapping labels
# 20647058_AGGREGATED.ann: overlapping labels
# 11778352_AGGREGATED.ann: overlapping labels
# 11378833_AGGREGATED.ann: overlapping labels
# 19590075_AGGREGATED.ann: overlapping labels
# 16911869_AGGREGATED.ann: overlapping labels
# 23886027_AGGREGATED.ann: overlapping labels
# 8259746_AGGREGATED.ann: overlapping labels
# 22421496_AGGREGATED.ann: overlapping labels
# 8752181_AGGREGATED.ann: overlapping labels
# 19368937_AGGREGATED.ann: overlapping labels
# 10080319_AGGREGATED.ann: overlapping labels
# 15956086_AGGREGATED.ann: overlapping labels
# 22574591_AGGREGATED.ann: overlapping labels
# 22496207_AGGREGATED.ann: overlapping labels
# 10811665_AGGREGATED.ann: overlapping labels
# 21237718_AGGREGATED.ann: overlapping labels
# 12452980_AGGREGATED.ann: overlapping labels
# 21639907_AGGREGATED.ann: overlapping labels
# 16109116_AGGREGATED.ann: overlapping labels
# 20452382_AGGREGATED.ann: overlapping labels
# 16855426_AGGREGATED.ann: overlapping labels
# 21946197_AGGREGATED.ann: overlapping labels
# 20159310_AGGREGATED.ann: overlapping labels
# 10969304_AGGREGATED.ann: overlapping labels
# 3207656_AGGREGATED.ann: overlapping labels
# 26121801_AGGREGATED.ann: overlapping labels
# 19807791_AGGREGATED.ann: overlapping labels
# 3538985_AGGREGATED.ann: overlapping labels
# 10651597_AGGREGATED.ann: overlapping labels
# 8708224_AGGREGATED.ann: overlapping labels
# 17321529_AGGREGATED.ann: overlapping labels
# 15358441_AGGREGATED.ann: overlapping labels
# 22964266_AGGREGATED.ann: overlapping labels
# 10084579_AGGREGATED.ann: overlapping labels
# 15132762_AGGREGATED.ann: overlapping labels
# 3287226_AGGREGATED.ann: overlapping labels
# 21849168_AGGREGATED.ann: overlapping labels
# 12855087_AGGREGATED.ann: overlapping labels
# 19716589_AGGREGATED.ann: overlapping labels
# 16791814_AGGREGATED.ann: overlapping labels
# 16048456_AGGREGATED.ann: overlapping labels
# 10355394_AGGREGATED.ann: overlapping labels
# 22214113_AGGREGATED.ann: overlapping labels
# 4448416_AGGREGATED.ann: overlapping labels
# 20562617_AGGREGATED.ann: overlapping labels
# 18711222_AGGREGATED.ann: overlapping labels
# 9820191_AGGREGATED.ann: overlapping labels
# 15176685_AGGREGATED.ann: overlapping labels
# 18704672_AGGREGATED.ann: overlapping labels
# 19965647_AGGREGATED.ann: overlapping labels
# 7997384_AGGREGATED.ann: overlapping labels
# 15200998_AGGREGATED.ann: overlapping labels
# 21463068_AGGREGATED.ann: overlapping labels
# 11348533_AGGREGATED.ann: overlapping labels
# 500415_AGGREGATED.ann: overlapping labels
# 20537413_AGGREGATED.ann: overlapping labels
# 19436938_AGGREGATED.ann: overlapping labels
# 24391123_AGGREGATED.ann: overlapping labels
# 8403910_AGGREGATED.ann: overlapping labels
# 23212807_AGGREGATED.ann: overlapping labels
# 19174717_AGGREGATED.ann: overlapping labels
# 11888774_AGGREGATED.ann: overlapping labels
# 10971307_AGGREGATED.ann: overlapping labels
# 17624203_AGGREGATED.ann: overlapping labels
# 6496450_AGGREGATED.ann: overlapping labels
# 9101947_AGGREGATED.ann: overlapping labels
# 8735490_AGGREGATED.ann: overlapping labels
# 23257173_AGGREGATED.ann: overlapping labels
# 7608801_AGGREGATED.ann: overlapping labels
# 24457421_AGGREGATED.ann: overlapping labels
# 9652561_AGGREGATED.ann: overlapping labels
# 9512152_AGGREGATED.ann: overlapping labels
# 9786491_AGGREGATED.ann: overlapping labels
# 17393618_AGGREGATED.ann: overlapping labels
# 8582461_AGGREGATED.ann: overlapping labels
# 25252600_AGGREGATED.ann: overlapping labels
# 16904652_AGGREGATED.ann: overlapping labels
# 23952897_AGGREGATED.ann: overlapping labels
# 12084138_AGGREGATED.ann: overlapping labels
# 9495616_AGGREGATED.ann: overlapping labels
# 20526599_AGGREGATED.ann: overlapping labels
# 17715164_AGGREGATED.ann: overlapping labels
# 8159300_AGGREGATED.ann: overlapping labels
# 17198705_AGGREGATED.ann: overlapping labels
# 25283504_AGGREGATED.ann: overlapping labels
# 18249478_AGGREGATED.ann: overlapping labels
# 3299950_AGGREGATED.ann: overlapping labels
# 20569725_AGGREGATED.ann: overlapping labels
# 25546925_AGGREGATED.ann: overlapping labels
# 15897310_AGGREGATED.ann: overlapping labels
# 19763803_AGGREGATED.ann: overlapping labels
# 8770026_AGGREGATED.ann: overlapping labels
# 17050770_AGGREGATED.ann: overlapping labels
# 1751081_AGGREGATED.ann: overlapping labels
# 18273636_AGGREGATED.ann: overlapping labels
# 18289310_AGGREGATED.ann: overlapping labels
# 15746053_AGGREGATED.ann: overlapping labels
# 27036056_AGGREGATED.ann: overlapping labels
# 22006202_AGGREGATED.ann: overlapping labels
# 16855475_AGGREGATED.ann: overlapping labels
# 21661164_AGGREGATED.ann: overlapping labels
# 3131904_AGGREGATED.ann: overlapping labels
# 8872499_AGGREGATED.ann: overlapping labels
# 11876712_AGGREGATED.ann: overlapping labels
# 9862848_AGGREGATED.ann: overlapping labels
# 26279130_AGGREGATED.ann: overlapping labels
# 12375315_AGGREGATED.ann: overlapping labels
# 8580292_AGGREGATED.ann: overlapping labels
# 23869063_AGGREGATED.ann: overlapping labels
# 23768813_AGGREGATED.ann: overlapping labels
# 19682342_AGGREGATED.ann: overlapping labels
# 15482502_AGGREGATED.ann: overlapping labels
# 15309442_AGGREGATED.ann: overlapping labels
# 9182738_AGGREGATED.ann: overlapping labels
# 21410033_AGGREGATED.ann: overlapping labels
# 23483320_AGGREGATED.ann: overlapping labels
# 3877292_AGGREGATED.ann: overlapping labels
# 17208334_AGGREGATED.ann: overlapping labels
# 22989372_AGGREGATED.ann: overlapping labels
# 9700583_AGGREGATED.ann: overlapping labels
# 17597498_AGGREGATED.ann: overlapping labels
# 23192919_AGGREGATED.ann: overlapping labels
# 11318022_AGGREGATED.ann: overlapping labels
# 16379507_AGGREGATED.ann: overlapping labels
# 21272822_AGGREGATED.ann: overlapping labels
# 23128568_AGGREGATED.ann: overlapping labels
# 25492271_AGGREGATED.ann: overlapping labels
# 16104966_AGGREGATED.ann: overlapping labels
# 10992833_AGGREGATED.ann: overlapping labels
# 18467912_AGGREGATED.ann: overlapping labels
# 22683613_AGGREGATED.ann: overlapping labels
# 3220672_AGGREGATED.ann: overlapping labels
# 2973215_AGGREGATED.ann: overlapping labels
# 25265770_AGGREGATED.ann: overlapping labels
# 10986363_AGGREGATED.ann: overlapping labels
# 24263699_AGGREGATED.ann: overlapping labels
# 8260242_AGGREGATED.ann: overlapping labels
# 20023215_AGGREGATED.ann: overlapping labels
# 11683967_AGGREGATED.ann: overlapping labels
# 7829176_AGGREGATED.ann: overlapping labels
# 10429005_AGGREGATED.ann: overlapping labels
# 6390445_AGGREGATED.ann: overlapping labels
# 15625713_AGGREGATED.ann: overlapping labels
# 7390376_AGGREGATED.ann: overlapping labels
# 7865492_AGGREGATED.ann: overlapping labels
# 18453793_AGGREGATED.ann: overlapping labels
# 22014222_AGGREGATED.ann: overlapping labels
# 11377310_AGGREGATED.ann: overlapping labels
# 20337981_AGGREGATED.ann: overlapping labels
# 22419350_AGGREGATED.ann: overlapping labels
# 14736356_AGGREGATED.ann: overlapping labels
# 22377512_AGGREGATED.ann: overlapping labels
# 6761890_AGGREGATED.ann: overlapping labels
# 19207781_AGGREGATED.ann: overlapping labels
# 9647873_AGGREGATED.ann: overlapping labels
# 9935021_AGGREGATED.ann: overlapping labels
# 12378396_AGGREGATED.ann: overlapping labels
# 18547294_AGGREGATED.ann: overlapping labels
# 24635110_AGGREGATED.ann: overlapping labels
# 18845806_AGGREGATED.ann: overlapping labels
# 7761011_AGGREGATED.ann: overlapping labels
# 19833610_AGGREGATED.ann: overlapping labels
# 23838727_AGGREGATED.ann: overlapping labels
# 23510984_AGGREGATED.ann: overlapping labels
# 9174876_AGGREGATED.ann: overlapping labels
# 23000125_AGGREGATED.ann: overlapping labels
# 15472677_AGGREGATED.ann: overlapping labels
# 8837189_AGGREGATED.ann: overlapping labels
# 23896590_AGGREGATED.ann: overlapping labels
# 19470807_AGGREGATED.ann: overlapping labels
# 25893544_AGGREGATED.ann: overlapping labels
# 17979862_AGGREGATED.ann: overlapping labels
# 9751681_AGGREGATED.ann: overlapping labels
# 12551867_AGGREGATED.ann: overlapping labels
# 22311204_AGGREGATED.ann: overlapping labels
# 23624061_AGGREGATED.ann: overlapping labels
# 23713303_AGGREGATED.ann: overlapping labels
# 2454375_AGGREGATED.ann: overlapping labels
# 17698601_AGGREGATED.ann: overlapping labels
# 20973712_AGGREGATED.ann: overlapping labels
# 25282520_AGGREGATED.ann: overlapping labels
# 15317925_AGGREGATED.ann: overlapping labels
# 19918712_AGGREGATED.ann: overlapping labels
# 19324944_AGGREGATED.ann: overlapping labels
# 19415409_AGGREGATED.ann: overlapping labels
# 8123947_AGGREGATED.ann: overlapping labels
# 9205768_AGGREGATED.ann: overlapping labels
# 21596605_AGGREGATED.ann: overlapping labels
# 14567804_AGGREGATED.ann: overlapping labels
# 19011453_AGGREGATED.ann: overlapping labels
# 26052790_AGGREGATED.ann: overlapping labels
# 12239448_AGGREGATED.ann: overlapping labels
# 22987458_AGGREGATED.ann: overlapping labels
# 19780729_AGGREGATED.ann: overlapping labels
# 12458862_AGGREGATED.ann: overlapping labels
# 19996335_AGGREGATED.ann: overlapping labels
# 25246693_AGGREGATED.ann: overlapping labels
# 10807619_AGGREGATED.ann: overlapping labels
# 12823122_AGGREGATED.ann: overlapping labels
# 22348801_AGGREGATED.ann: overlapping labels
# 15169706_AGGREGATED.ann: overlapping labels
# 17322624_AGGREGATED.ann: overlapping labels
# 24878589_AGGREGATED.ann: overlapping labels
# 15571828_AGGREGATED.ann: overlapping labels
# 24652860_AGGREGATED.ann: overlapping labels
# 17069545_AGGREGATED.ann: overlapping labels
# 26217065_AGGREGATED.ann: overlapping labels
# 12169964_AGGREGATED.ann: overlapping labels
# 11411192_AGGREGATED.ann: overlapping labels
# 3673207_AGGREGATED.ann: overlapping labels
# 10036953_AGGREGATED.ann: overlapping labels
# 3134815_AGGREGATED.ann: overlapping labels
# 17666359_AGGREGATED.ann: overlapping labels
# 14998846_AGGREGATED.ann: overlapping labels
# 15068403_AGGREGATED.ann: overlapping labels
# 543887_AGGREGATED.ann: overlapping labels
# 15446660_AGGREGATED.ann: overlapping labels
# 24559095_AGGREGATED.ann: overlapping labels
# 3732715_AGGREGATED.ann: overlapping labels
# 12974687_AGGREGATED.ann: overlapping labels
# 8210973_AGGREGATED.ann: overlapping labels
# 20220293_AGGREGATED.ann: overlapping labels
# 1617528_AGGREGATED.ann: overlapping labels
# 21846665_AGGREGATED.ann: overlapping labels
# 23233021_AGGREGATED.ann: overlapping labels
# 22133872_AGGREGATED.ann: overlapping labels
# 20199680_AGGREGATED.ann: overlapping labels
# 15734707_AGGREGATED.ann: overlapping labels
# 18957505_AGGREGATED.ann: overlapping labels
# 15528910_AGGREGATED.ann: overlapping labels
# 19713225_AGGREGATED.ann: overlapping labels
# 23360819_AGGREGATED.ann: overlapping labels
# 2008691_AGGREGATED.ann: overlapping labels
# 22273828_AGGREGATED.ann: overlapping labels
# 15965438_AGGREGATED.ann: overlapping labels
# 7492424_AGGREGATED.ann: overlapping labels
# 16753722_AGGREGATED.ann: overlapping labels
# 9825232_AGGREGATED.ann: overlapping labels
# 18488812_AGGREGATED.ann: overlapping labels
# 22921159_AGGREGATED.ann: overlapping labels
# 15013543_AGGREGATED.ann: overlapping labels
# 23870440_AGGREGATED.ann: overlapping labels
# 3957541_AGGREGATED.ann: overlapping labels
# 26499867_AGGREGATED.ann: overlapping labels
# 7047002_AGGREGATED.ann: overlapping labels
# 9825384_AGGREGATED.ann: overlapping labels
# 3300436_AGGREGATED.ann: overlapping labels
# 15474171_AGGREGATED.ann: overlapping labels
# 9553982_AGGREGATED.ann: overlapping labels
# 15673894_AGGREGATED.ann: overlapping labels
# 22565413_AGGREGATED.ann: overlapping labels
# 19301089_AGGREGATED.ann: overlapping labels
# 12182253_AGGREGATED.ann: overlapping labels
# 19895777_AGGREGATED.ann: overlapping labels
# 25047312_AGGREGATED.ann: overlapping labels
# 17767200_AGGREGATED.ann: overlapping labels
# 8454478_AGGREGATED.ann: overlapping labels
# 23659834_AGGREGATED.ann: overlapping labels
# 17848325_AGGREGATED.ann: overlapping labels
# 21429223_AGGREGATED.ann: overlapping labels
# 11379334_AGGREGATED.ann: overlapping labels
# 9469367_AGGREGATED.ann: overlapping labels
# 1742482_AGGREGATED.ann: overlapping labels
# 4127641_AGGREGATED.ann: overlapping labels
# 23964752_AGGREGATED.ann: overlapping labels
# 15463829_AGGREGATED.ann: overlapping labels
# 7211918_AGGREGATED.ann: overlapping labels
# 6113821_AGGREGATED.ann: overlapping labels
# 1919850_AGGREGATED.ann: overlapping labels
# 17179873_AGGREGATED.ann: overlapping labels
# 9892252_AGGREGATED.ann: overlapping labels
# 11100343_AGGREGATED.ann: overlapping labels
# 23021898_AGGREGATED.ann: overlapping labels
# 6849726_AGGREGATED.ann: overlapping labels
# ...
# 8305277_AGGREGATED.ann: overlapping labels
# 16076379_AGGREGATED.ann: overlapping labels
# 23092665_AGGREGATED.ann: overlapping labels
# 17972479_AGGREGATED.ann: overlapping labels
# 14655885_AGGREGATED.ann: overlapping labels
# 9474454_AGGREGATED.ann: overlapping labels
# 23980091_AGGREGATED.ann: overlapping labels
# 25195982_AGGREGATED.ann: overlapping labels
# 7956382_AGGREGATED.ann: overlapping labels
# 19798489_AGGREGATED.ann: overlapping labels
# 8852235_AGGREGATED.ann: overlapping labels
# 1854617_AGGREGATED.ann: overlapping labels
# 15774238_AGGREGATED.ann: overlapping labels
# 16503545_AGGREGATED.ann: overlapping labels
# 24749259_AGGREGATED.ann: overlapping labels
# 16908870_AGGREGATED.ann: overlapping labels
# 21900715_AGGREGATED.ann: overlapping labels
# 3189201_AGGREGATED.ann: overlapping labels
# 3550340_AGGREGATED.ann: overlapping labels
# 10148879_AGGREGATED.ann: overlapping labels
# 12576957_AGGREGATED.ann: overlapping labels
# 7010662_AGGREGATED.ann: overlapping labels
# 3546120_AGGREGATED.ann: overlapping labels
# 12239480_AGGREGATED.ann: overlapping labels
# 15673999_AGGREGATED.ann: overlapping labels
# 10224577_AGGREGATED.ann: overlapping labels
# 8624384_AGGREGATED.ann: overlapping labels
# 7733183_AGGREGATED.ann: overlapping labels
# 24004700_AGGREGATED.ann: overlapping labels
# 2885607_AGGREGATED.ann: overlapping labels
# 15101027_AGGREGATED.ann: overlapping labels
# 22985336_AGGREGATED.ann: overlapping labels
# 21425723_AGGREGATED.ann: overlapping labels
# 19169102_AGGREGATED.ann: overlapping labels
# 22527308_AGGREGATED.ann: overlapping labels
# 396086_AGGREGATED.ann: overlapping labels
# 19998583_AGGREGATED.ann: overlapping labels
# 3112261_AGGREGATED.ann: overlapping labels
# 19081412_AGGREGATED.ann: overlapping labels
# 21226576_AGGREGATED.ann: overlapping labels
# 1853794_AGGREGATED.ann: overlapping labels
# 22967497_AGGREGATED.ann: overlapping labels
# 25187485_AGGREGATED.ann: overlapping labels
# 3385217_AGGREGATED.ann: overlapping labels
# 1350581_AGGREGATED.ann: overlapping labels
# 11191952_AGGREGATED.ann: overlapping labels
# 1497159_AGGREGATED.ann: overlapping labels
# 12830748_AGGREGATED.ann: overlapping labels
# 17410213_AGGREGATED.ann: overlapping labels
# 24626433_AGGREGATED.ann: overlapping labels
# 22446996_AGGREGATED.ann: overlapping labels
# 7995312_AGGREGATED.ann: overlapping labels
# 10714690_AGGREGATED.ann: overlapping labels
# 9395031_AGGREGATED.ann: overlapping labels
# 18541792_AGGREGATED.ann: overlapping labels
# 15895329_AGGREGATED.ann: overlapping labels
# 23332872_AGGREGATED.ann: overlapping labels
# 9413463_AGGREGATED.ann: overlapping labels
# 20486273_AGGREGATED.ann: overlapping labels
# 1622739_AGGREGATED.ann: overlapping labels
# 24526141_AGGREGATED.ann: overlapping labels
# 20035541_AGGREGATED.ann: overlapping labels
# 7963648_AGGREGATED.ann: overlapping labels
# 2208619_AGGREGATED.ann: overlapping labels
# 10741095_AGGREGATED.ann: overlapping labels
# 25475363_AGGREGATED.ann: overlapping labels
# 25659440_AGGREGATED.ann: overlapping labels
# 8331682_AGGREGATED.ann: overlapping labels
# 11315533_AGGREGATED.ann: overlapping labels
# 2195054_AGGREGATED.ann: overlapping labels
# 3146231_AGGREGATED.ann: overlapping labels
# 7706148_AGGREGATED.ann: overlapping labels
# 6836750_AGGREGATED.ann: overlapping labels
# 24021291_AGGREGATED.ann: overlapping labels
# 8396304_AGGREGATED.ann: overlapping labels
# 11154142_AGGREGATED.ann: overlapping labels
# 21830957_AGGREGATED.ann: overlapping labels
# 3630589_AGGREGATED.ann: overlapping labels
# 19171500_AGGREGATED.ann: overlapping labels
# 15916851_AGGREGATED.ann: overlapping labels
# 18208642_AGGREGATED.ann: overlapping labels
# 18082528_AGGREGATED.ann: overlapping labels
# 11741555_AGGREGATED.ann: overlapping labels
# 17572835_AGGREGATED.ann: overlapping labels
# 19594501_AGGREGATED.ann: overlapping labels
# 23292082_AGGREGATED.ann: overlapping labels
# 24781441_AGGREGATED.ann: overlapping labels
# 20019137_AGGREGATED.ann: overlapping labels
# 18701020_AGGREGATED.ann: overlapping labels
# 10361648_AGGREGATED.ann: overlapping labels
# 17721955_AGGREGATED.ann: overlapping labels
# 1715416_AGGREGATED.ann: overlapping labels
# 6360688_AGGREGATED.ann: overlapping labels
# 20615885_AGGREGATED.ann: overlapping labels
# 10758987_AGGREGATED.ann: overlapping labels
# 22712208_AGGREGATED.ann: overlapping labels
# 18391640_AGGREGATED.ann: overlapping labels
# 701664_AGGREGATED.ann: overlapping labels
# 10870534_AGGREGATED.ann: overlapping labels
# 20070284_AGGREGATED.ann: overlapping labels
# 21434781_AGGREGATED.ann: overlapping labels
# 8639070_AGGREGATED.ann: overlapping labels
# 2690913_AGGREGATED.ann: overlapping labels
# 23394513_AGGREGATED.ann: overlapping labels
# 11459079_AGGREGATED.ann: overlapping labels
# 19051459_AGGREGATED.ann: overlapping labels
# 17657694_AGGREGATED.ann: overlapping labels
# 23802768_AGGREGATED.ann: overlapping labels
# 2168532_AGGREGATED.ann: overlapping labels
# 15220594_AGGREGATED.ann: overlapping labels
# 15530681_AGGREGATED.ann: overlapping labels
# 3119086_AGGREGATED.ann: overlapping labels
# 22045826_AGGREGATED.ann: overlapping labels
# 8275152_AGGREGATED.ann: overlapping labels
# 2108990_AGGREGATED.ann: overlapping labels
# 1286738_AGGREGATED.ann: overlapping labels
# 15088136_AGGREGATED.ann: overlapping labels
# 10052279_AGGREGATED.ann: overlapping labels
# 21087288_AGGREGATED.ann: overlapping labels
# 17149529_AGGREGATED.ann: overlapping labels
# 12790985_AGGREGATED.ann: overlapping labels
# 16845576_AGGREGATED.ann: overlapping labels
# 16437191_AGGREGATED.ann: overlapping labels
# 10636373_AGGREGATED.ann: overlapping labels
# 7692028_AGGREGATED.ann: overlapping labels
# 17375984_AGGREGATED.ann: overlapping labels
# 25623276_AGGREGATED.ann: overlapping labels
# 25616941_AGGREGATED.ann: overlapping labels
# 11156811_AGGREGATED.ann: overlapping labels
# 8964276_AGGREGATED.ann: overlapping labels
# 25953148_AGGREGATED.ann: overlapping labels
# 12844138_AGGREGATED.ann: overlapping labels
# 8367775_AGGREGATED.ann: overlapping labels
# 17934678_AGGREGATED.ann: overlapping labels
# 25287262_AGGREGATED.ann: overlapping labels
# 20843746_AGGREGATED.ann: overlapping labels
# 24694748_AGGREGATED.ann: overlapping labels
# 11069570_AGGREGATED.ann: overlapping labels
# 11159256_AGGREGATED.ann: overlapping labels
# 17471343_AGGREGATED.ann: overlapping labels
# 25441055_AGGREGATED.ann: overlapping labels
# 11835021_AGGREGATED.ann: overlapping labels
# 22129897_AGGREGATED.ann: overlapping labels
# 21072224_AGGREGATED.ann: overlapping labels
# 7810153_AGGREGATED.ann: overlapping labels
# 15377466_AGGREGATED.ann: overlapping labels
# 22750958_AGGREGATED.ann: overlapping labels
# 24785600_AGGREGATED.ann: overlapping labels
# 21214129_AGGREGATED.ann: overlapping labels
# 21672315_AGGREGATED.ann: overlapping labels
# 12585724_AGGREGATED.ann: overlapping labels
# 11013281_AGGREGATED.ann: overlapping labels
# 10599355_AGGREGATED.ann: overlapping labels
# 19199847_AGGREGATED.ann: overlapping labels
# 7755996_AGGREGATED.ann: overlapping labels
# 22008443_AGGREGATED.ann: overlapping labels
# 9642484_AGGREGATED.ann: overlapping labels
# 17631392_AGGREGATED.ann: overlapping labels
# 11705818_AGGREGATED.ann: overlapping labels
# 18633049_AGGREGATED.ann: overlapping labels
# 7774537_AGGREGATED.ann: overlapping labels
# 21692873_AGGREGATED.ann: overlapping labels
# 16880243_AGGREGATED.ann: overlapping labels
# 21869698_AGGREGATED.ann: overlapping labels
# 22834767_AGGREGATED.ann: overlapping labels
# 19111789_AGGREGATED.ann: overlapping labels
# 21629200_AGGREGATED.ann: overlapping labels
# 11570966_AGGREGATED.ann: overlapping labels
# 20881754_AGGREGATED.ann: overlapping labels
# 7032533_AGGREGATED.ann: overlapping labels
# 9703286_AGGREGATED.ann: overlapping labels
# 8741469_AGGREGATED.ann: overlapping labels
# 15733631_AGGREGATED.ann: overlapping labels
# 1937073_AGGREGATED.ann: overlapping labels
# 24237999_AGGREGATED.ann: overlapping labels
# 3839157_AGGREGATED.ann: overlapping labels
# 25149412_AGGREGATED.ann: overlapping labels
# 20038728_AGGREGATED.ann: overlapping labels
# 688257_AGGREGATED.ann: overlapping labels
# 3950826_AGGREGATED.ann: overlapping labels
# 6938012_AGGREGATED.ann: overlapping labels
# 7208897_AGGREGATED.ann: overlapping labels
# 1707797_AGGREGATED.ann: overlapping labels
# 12635578_AGGREGATED.ann: overlapping labels
# 23274597_AGGREGATED.ann: overlapping labels
# 10768434_AGGREGATED.ann: overlapping labels
# 2474057_AGGREGATED.ann: overlapping labels
# 1894676_AGGREGATED.ann: overlapping labels
# 19022794_AGGREGATED.ann: overlapping labels
# 350565_AGGREGATED.ann: overlapping labels
# 24691455_AGGREGATED.ann: overlapping labels
# 22659656_AGGREGATED.ann: overlapping labels
# 15689088_AGGREGATED.ann: overlapping labels
# 24213956_AGGREGATED.ann: overlapping labels
# 24074927_AGGREGATED.ann: overlapping labels
# 17224353_AGGREGATED.ann: overlapping labels
# 9553664_AGGREGATED.ann: overlapping labels
# 12792318_AGGREGATED.ann: overlapping labels
# 21600592_AGGREGATED.ann: overlapping labels
# 25892145_AGGREGATED.ann: overlapping labels
# 8623957_AGGREGATED.ann: overlapping labels
# 15622265_AGGREGATED.ann: overlapping labels
# 12653895_AGGREGATED.ann: overlapping labels
# 19371887_AGGREGATED.ann: overlapping labels
# 16399263_AGGREGATED.ann: overlapping labels
# 7528271_AGGREGATED.ann: overlapping labels
# 21801451_AGGREGATED.ann: overlapping labels
# 19912211_AGGREGATED.ann: overlapping labels
# 14670288_AGGREGATED.ann: overlapping labels
# 20590478_AGGREGATED.ann: overlapping labels
# 2831788_AGGREGATED.ann: overlapping labels
# 22219012_AGGREGATED.ann: overlapping labels
# 15978926_AGGREGATED.ann: overlapping labels
# 22050796_AGGREGATED.ann: overlapping labels
# 10939601_AGGREGATED.ann: overlapping labels
# 23870503_AGGREGATED.ann: overlapping labels
# 12482473_AGGREGATED.ann: overlapping labels
# 8568534_AGGREGATED.ann: overlapping labels
# 18470779_AGGREGATED.ann: overlapping labels
# 22240882_AGGREGATED.ann: overlapping labels
# 6850464_AGGREGATED.ann: overlapping labels
# 12895217_AGGREGATED.ann: overlapping labels
# 7053590_AGGREGATED.ann: overlapping labels
# 21552085_AGGREGATED.ann: overlapping labels
# 24104511_AGGREGATED.ann: overlapping labels
# 9229263_AGGREGATED.ann: overlapping labels
# 21844080_AGGREGATED.ann: overlapping labels
# 25515056_AGGREGATED.ann: overlapping labels
# 15264973_AGGREGATED.ann: overlapping labels
# 23619951_AGGREGATED.ann: overlapping labels
# 21266651_AGGREGATED.ann: overlapping labels
# 1578953_AGGREGATED.ann: overlapping labels
# 17316832_AGGREGATED.ann: overlapping labels
# 25465111_AGGREGATED.ann: overlapping labels
# 20124059_AGGREGATED.ann: overlapping labels
# 12384805_AGGREGATED.ann: overlapping labels
# 2576261_AGGREGATED.ann: overlapping labels
# 20661580_AGGREGATED.ann: overlapping labels
# 3174738_AGGREGATED.ann: overlapping labels
# 8487324_AGGREGATED.ann: overlapping labels
# 4752239_AGGREGATED.ann: overlapping labels
# 15241630_AGGREGATED.ann: overlapping labels
# 24324379_AGGREGATED.ann: overlapping labels
# 1516345_AGGREGATED.ann: overlapping labels
# 17365975_AGGREGATED.ann: overlapping labels
# 15141043_AGGREGATED.ann: overlapping labels
# 19153828_AGGREGATED.ann: overlapping labels
# 24534270_AGGREGATED.ann: overlapping labels
# 2286596_AGGREGATED.ann: overlapping labels
# 18686184_AGGREGATED.ann: overlapping labels
# 16923411_AGGREGATED.ann: overlapping labels
# 3116609_AGGREGATED.ann: overlapping labels
# 21851906_AGGREGATED.ann: overlapping labels
# 2374275_AGGREGATED.ann: overlapping labels
# 15641975_AGGREGATED.ann: overlapping labels
# 9894936_AGGREGATED.ann: overlapping labels
# 16651950_AGGREGATED.ann: overlapping labels
# 2493733_AGGREGATED.ann: overlapping labels
# 25262168_AGGREGATED.ann: overlapping labels
# 21419391_AGGREGATED.ann: overlapping labels
# 25459500_AGGREGATED.ann: overlapping labels
# 23386127_AGGREGATED.ann: overlapping labels
# 21220480_AGGREGATED.ann: overlapping labels
# 1396108_AGGREGATED.ann: overlapping labels
# 2162258_AGGREGATED.ann: overlapping labels
# 18948032_AGGREGATED.ann: overlapping labels
# 14616872_AGGREGATED.ann: overlapping labels
# 23586852_AGGREGATED.ann: overlapping labels
# 11064610_AGGREGATED.ann: overlapping labels
# 10482855_AGGREGATED.ann: overlapping labels
# 19691092_AGGREGATED.ann: overlapping labels
# 9164427_AGGREGATED.ann: overlapping labels
# 19931151_AGGREGATED.ann: overlapping labels
# 2023746_AGGREGATED.ann: overlapping labels
# 25066648_AGGREGATED.ann: overlapping labels
# 23862237_AGGREGATED.ann: overlapping labels
# 10861653_AGGREGATED.ann: overlapping labels
# 9493479_AGGREGATED.ann: overlapping labels
# 11710599_AGGREGATED.ann: overlapping labels
# 9919095_AGGREGATED.ann: overlapping labels
# 26046796_AGGREGATED.ann: overlapping labels
# 345802_AGGREGATED.ann: overlapping labels
# 20506785_AGGREGATED.ann: overlapping labels
# 12093332_AGGREGATED.ann: overlapping labels
# 1911013_AGGREGATED.ann: overlapping labels
# 6261782_AGGREGATED.ann: overlapping labels
# 25861158_AGGREGATED.ann: overlapping labels
# 11319711_AGGREGATED.ann: overlapping labels
# 7923712_AGGREGATED.ann: overlapping labels
# 26058489_AGGREGATED.ann: overlapping labels
# 8338088_AGGREGATED.ann: overlapping labels
# 2184179_AGGREGATED.ann: overlapping labels
# 8126502_AGGREGATED.ann: overlapping labels
# 1575174_AGGREGATED.ann: overlapping labels
# 22414202_AGGREGATED.ann: overlapping labels
# 3940160_AGGREGATED.ann: overlapping labels
# 3594511_AGGREGATED.ann: overlapping labels
# 8394956_AGGREGATED.ann: overlapping labels
# 12704402_AGGREGATED.ann: overlapping labels
# 26554619_AGGREGATED.ann: overlapping labels
# 1593244_AGGREGATED.ann: overlapping labels
# 24768960_AGGREGATED.ann: overlapping labels
# 8208469_AGGREGATED.ann: overlapping labels
# 24689172_AGGREGATED.ann: overlapping labels
# 9076457_AGGREGATED.ann: overlapping labels
# 17929164_AGGREGATED.ann: overlapping labels
# 10208073_AGGREGATED.ann: overlapping labels
# 15383046_AGGREGATED.ann: overlapping labels
# 9987969_AGGREGATED.ann: overlapping labels
# 9769784_AGGREGATED.ann: overlapping labels
# 22686292_AGGREGATED.ann: overlapping labels
# 22488107_AGGREGATED.ann: overlapping labels
# 25449737_AGGREGATED.ann: overlapping labels
# 24372367_AGGREGATED.ann: overlapping labels
# 26279073_AGGREGATED.ann: overlapping labels
# 19357315_AGGREGATED.ann: overlapping labels
# 17286730_AGGREGATED.ann: overlapping labels
# 11863211_AGGREGATED.ann: overlapping labels
# 7235205_AGGREGATED.ann: overlapping labels
# 26665290_AGGREGATED.ann: overlapping labels
# 9105060_AGGREGATED.ann: overlapping labels
# 16230665_AGGREGATED.ann: overlapping labels
# 24324004_AGGREGATED.ann: overlapping labels
# 14649341_AGGREGATED.ann: overlapping labels
# 6729651_AGGREGATED.ann: overlapping labels
# 19552904_AGGREGATED.ann: overlapping labels
# 16125499_AGGREGATED.ann: overlapping labels
# 10594396_AGGREGATED.ann: overlapping labels
# 3287999_AGGREGATED.ann: overlapping labels
# 6374683_AGGREGATED.ann: overlapping labels
# 11860536_AGGREGATED.ann: overlapping labels
# 1300984_AGGREGATED.ann: overlapping labels
# 24371832_AGGREGATED.ann: overlapping labels
# 8507025_AGGREGATED.ann: overlapping labels
# 16128933_AGGREGATED.ann: overlapping labels
# 23660099_AGGREGATED.ann: overlapping labels
# 1878735_AGGREGATED.ann: overlapping labels
# 11253439_AGGREGATED.ann: overlapping labels
# 21189767_AGGREGATED.ann: overlapping labels
# 23605805_AGGREGATED.ann: overlapping labels
# 16757200_AGGREGATED.ann: overlapping labels
# 663366_AGGREGATED.ann: overlapping labels
# 15247730_AGGREGATED.ann: overlapping labels
# 23716409_AGGREGATED.ann: overlapping labels
# 19397502_AGGREGATED.ann: overlapping labels
# 5341828_AGGREGATED.ann: overlapping labels
# 18205945_AGGREGATED.ann: overlapping labels
# 3548803_AGGREGATED.ann: overlapping labels
# 7037697_AGGREGATED.ann: overlapping labels
# 10735838_AGGREGATED.ann: overlapping labels
# 25292351_AGGREGATED.ann: overlapping labels
# 24338168_AGGREGATED.ann: overlapping labels
# 8940983_AGGREGATED.ann: overlapping labels
# 10602739_AGGREGATED.ann: overlapping labels
# 17907108_AGGREGATED.ann: overlapping labels
# 14690574_AGGREGATED.ann: overlapping labels
# 8858230_AGGREGATED.ann: overlapping labels
# 11838820_AGGREGATED.ann: overlapping labels
# 392623_AGGREGATED.ann: overlapping labels
# 23890774_AGGREGATED.ann: overlapping labels
# 20530107_AGGREGATED.ann: overlapping labels
# 7891203_AGGREGATED.ann: overlapping labels
# 15162076_AGGREGATED.ann: overlapping labels
# 9514454_AGGREGATED.ann: overlapping labels
# 8873520_AGGREGATED.ann: overlapping labels
# Total overlaps: 4779/4802

# %% [markdown]
# So there are overlapping entities...that's definitely expected. Our next step is to convert these entities into the spaCy serialized format.

# %%
import re
from typing import Tuple

import numpy as np
import spacy
from spacy.tokens import Doc, Span
from spacy.util import get_words_and_spaces

nlp = spacy.blank("en")


def convert_to_doc(nlp, file_id: str) -> Tuple[Doc, str, List[str]]:
    """Convert raw text and tokens into a Doc object."""
    # Get the text and the tokens
    #text = re.sub('"', "", (TEXT_DIR / f"{file_id}.text").read_text())
    #text = re.sub("\n", "", text)
    text = (TEXT_DIR / f"{file_id}.tokens").read_text()
    tokens = text.split(" ")

    # Create a Doc object
    words, spaces = get_words_and_spaces(words=tokens, text=text)
    doc = Doc(nlp.vocab, words=words, spaces=spaces)
    return doc, text, tokens


def _get_contiguous_tokens(labels: List[int]) -> List:
    """Get contiguous tokens that can be used for creating Spans
    
    Remember that when you make the actual spans, you need to add +1 to 
    the end token. This is because you want to pas the index of the first
    token 'after' the span.

    [0, 1, 1, 0, 1, 1] -> [(1, 2), (4, 5)]
    """
    indices = np.asarray([i for i, x in enumerate(labels) if x])
    if np.all((indices == 0)):
        return []
    else:
        contig = np.split(indices, np.where(np.diff(indices) != 1)[0] + 1)
        span_indices = [(c[0],) if len(c) == 1 else (c[0], c[-1]) for c in contig]
        return span_indices


def attach_spans_to_doc(doc: Doc, file_id: str, span_key: str = "sc") -> Doc:
    """Attach spans to the spaCy Doc"""
    # Get annotations
    directories = [PARTICIPANTS_DIR, INTERVENTIONS_DIR, OUTCOMES_DIR]
    labels = ["PARTICIPANTS", "INTERVENTIONS", "OUTCOMES"]
    annotations = {l: get_annotations(list(d.glob(f"**/{file_id}_AGGREGATED.ann"))[0]) for d, l in zip(directories, labels)}
    
    # Sanity-check if all tokens are of the same length
    assert all([len(doc) == len(a) for a in annotations.values()]), f"Misaligned tokens in {file_id}"

    spans = []
    for annot, labels in annotations.items():
        # Get the token indices (where the value is 1)
        indices = _get_contiguous_tokens(labels)
        if indices:
            for idx in indices:
                start = idx[0]
                end = idx[0] if len(idx) == 1 else idx[-1]
                spans.append(Span(doc, start, end + 1, label=annot))

    doc.spans[span_key] = spans
    return doc

# %% [markdown]
# ## Prepare training and test datasets
#
# First, we need to get the IDs for each training and test dataset

# %%
def ids_only(s: str) -> str:
    return re.sub("\_AGGREGATED", "", s)

# Assumes that PARTICIPANTS_DIR is the same everywhere
train_file_ids = [ids_only(file.stem) for file in (PARTICIPANTS_DIR / "train").glob("*_AGGREGATED.ann")]
test_file_ids = [ids_only(file.stem) for file in (PARTICIPANTS_DIR / "test" / "gold").glob("*_AGGREGATED.ann")]


def to_spacy(file_id, nlp) -> Doc:
    doc, _, _ = convert_to_doc(nlp, file_id)
    doc = attach_spans_to_doc(doc, file_id)
    return doc

# %%
from spacy.tokens import DocBin

train_doc_bin = DocBin()
for idx, train_id in enumerate(train_file_ids):
    try:
        doc = to_spacy(train_id, nlp)
    except ValueError:
        print(f"Error in {train_id}")
    else:
        train_doc_bin.add(doc)

test_doc_bin = DocBin()
for idx, test_id in enumerate(test_file_ids):
    try:
        doc = to_spacy(test_id, nlp)
    except ValueError:
        print(f"Error in {test_id}")
    else:
        test_doc_bin.add(doc)
# Out:
# Processed 0 train files
# Processed 500 train files
# Processed 1000 train files
# Processed 1500 train files
# Processed 2000 train files
# Processed 2500 train files
# Processed 3000 train files
# Processed 3500 train files
# Processed 4000 train files
# Processed 4500 train files
# Processed 0 test files

# %%
train_doc_bin.to_disk(Path.cwd().parent / "assets" / "corpus" / "train.spacy")
test_doc_bin.to_disk(Path.cwd().parent / "assets" / "corpus" / "test.spacy")

# %%
# Things to do:
# 1. maybe put this in a script?
# 2. tomorrow, plan-out how you'll do the spancat training?
